# %% [markdown]
# <a href="https://colab.research.google.com/github/evanthacker/Great-Learning-MIT-Classes/blob/main/1_3_2_Line_Plot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **There are different visualization libraries in python, that provides an interface for drawing various graphics. Some most widely used libraries are Matplotlib, Seaborn, and Plotly.**

# %% [markdown]
# **Import the required libraries**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# to suppress warnings
import warnings 
warnings.filterwarnings('ignore')

# %% [markdown]
# Seaborn library provides a variety of datasets. Plot different visualization plots using various libraries for the 'tips' dataset.

# %%
# load the 'tips' dataset from seaborn
tips_data = sns.load_dataset('tips')

# display head() of the dataset
tips_data.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# **How to install Matplotlib?**

# %% [markdown]
# 1. You can use-

# %%
'!pip install matplotlib'
# Out:
# '!pip install matplotlib'

# %% [markdown]
# ## Line Plot

# %%
# data
X = np.linspace(1,20,100)
Y = np.exp(X)

# line plot
plt.plot(X,Y)
# display the plot
plt.show()

# %% [markdown]
# From the plot, it can be observed that as 'X' is increasing there is an exponential increase in Y.

# %% [markdown]
# **The above plot can be represented not only by a solid line, but also a dotted line with varied thickness. The points can be marked explicitly using any symbol.**

# %%
# data
X = np.linspace(1,20,100)
Y = np.exp(X)

# line plot
# the argument 'r*' plots each point as red '*'
plt.plot(X,Y, 'r*')

# display the plot
plt.show()

# %% [markdown]
# We can change the colors or shapes of the data points.
#
# There can be multiple time plots in one plot. Let's plot three plots together in a single graph. Also, add a plot title.

# %%
# data
#X = np.linspace(1,20,100)
Y1 = X
Y2 = np.square(X)
Y3 = np.sqrt(X)

# line plot
plt.plot(X,Y1,'r',X,Y2,'b',X,Y3,'g')

# add title to the plot
plt.title('line plot')


# display the plot
plt.show()

# %%
import matplotlib.pyplot as plt
X = [1,2,3]
Y = [11,12,13]
X1 = [1.5,2.5,3.5]
Y1 = [19,12,13]
plt.plot(X,Y,'r', X1,Y1,'b')
plt.show()

# %%
import matplotlib.pyplot as plt
X = [1,2,3]
Y = [11,12,13]
X1 = [1.5,2.5,3.5]
Y1 = [19,12,13]
plt.show()

# %%
import matplotlib.pyplot as plt
X = [1,2,3]
Y = [11,12,13]
X1 = [1.5,2.5,3.5]
Y1 = [19,12,13]
plot(X,Y, X1,Y1,'b','r')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_15536\1728381709.py in <module>
#       4 X1 = [1.5,2.5,3.5]
#       5 Y1 = [19,12,13]
# ----> 6 plot(X,Y, X1,Y1,'b','r')
#       7 plt.show()
#
# NameError: name 'plot' is not defined

# %%
import matplotlib.pyplot
import numpy as np
X = np.array([1, 2, 3, 4, 5])
Y = np.exp(X)
plt.plot(X,Y,'r.')
plt.show()

# %%
import matplotlib.pyplot
import numpy as np
X = np.array([1, 2, 3, 4, 5])
Y = np.exp(X)
plt.plot(X,Y,'b*')
plt.show()

# %%
import matplotlib.pyplot
import numpy as np
X = np.array([1, 2, 3, 4, 5])
Y = X**2
plt.plot(X,Y,'r.')
plt.show()

# %%
import matplotlib.pyplot
import numpy as np
X = np.array([1, 2, 3, 4, 5])
Y = np.exp(X)
plt.plot(X,Y,'r-')
plt.show()

# %%
import matplotlib.pyplot
import numpy as np
X = np.array([1, 2, 3, 4, 5])
Y = np.exp(X)
plt.plot(X,Y,'r.')
plt.show()

# %%
import matplotlib.pyplot
import numpy as np
X = np.array([1, 2, 3, 4, 5])
Y = X**2
plt.plot(X,Y,'r.')
plt.show()
